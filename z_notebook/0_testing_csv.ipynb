# %%
import pandas as pd

# %%
df = pd.read_csv('../data/silver/players/csv_clean/players_attacking.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 323 entries, 0 to 322
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         323 non-null    str
#  1   club         323 non-null    str
#  2   apps         323 non-null    int64
#  3   mins         323 non-null    int64
#  4   goals        323 non-null    int64
#  5   xg           323 non-null    float64
#  6   goals_vs_xg  323 non-null    float64
#  7   shots        323 non-null    int64
#  8   sot          323 non-null    int64
#  9   conv_pct     323 non-null    float64
#  10  xg_per_shot  323 non-null    float64
# dtypes: float64(4), int64(5), str(2)
# memory usage: 35.0 KB

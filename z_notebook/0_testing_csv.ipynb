# %%
# === Standard Library ===
import os
import warnings
from pathlib import Path

# === Data Manipulation ===
import numpy as np
import pandas as pd

# === Visualization ===
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
PROJECT_ROOT = Path.cwd().parent
data_path = PROJECT_ROOT / "data" / "gold" / "teams" / "teams_ml_features.csv"

df = pd.read_csv(data_path)

# %%
len(df.columns)
# Out:
# 54

# %%
df.head()
# Out:
#               club  att_goals  att_xg  att_goals_vs_xg  att_shots  att_sot  \
# 0           Alaves         44   47.05            -3.05        463      153
# 1  Athletic Bilbao         43   50.60            -7.60        522      172
# 2  Atlético Madrid         62   58.87             3.13        498      193
# 3        Barcelona         95   86.62             8.38        692      257
# 4       Celta Vigo         53   49.52             3.48        382      153
#
#    att_conversion_pct  att_xg_per_shot  att_goals_per_game  att_np_goals  ...  \
# 0                9.50             0.10                1.16            37  ...
# 1                8.24             0.10                1.13            38  ...
# 2               12.45             0.12                1.63            59  ...
# 3               13.73             0.13                2.50            88  ...
# 4               13.87             0.13                1.39            45  ...
#
#    seq_sequence_time  seq_buildups_total  seq_direct_attacks_total  \
# 0               8.01                  56                        47
# 1               8.12                  57                        42
# 2              11.03                 124                        64
# 3              14.22                 231                        65
# 4              11.65                 110                        53
#
#    seq_direct_attacks_goals  msc_fouls  msc_yellows  msc_reds  \
# 0                         1        539           86         5
# 1                         5        497           73         7
# 2                         2        399           77         5
# 3                         9        348           59         2
# 4                         4        425           71         1
#
#    msc_errors_lead_to_shot  msc_errors_lead_to_goal  msc_pens_conceded
# 0                       19                        4                  5
# 1                       27                        6                  6
# 2                       22                        4                  6
# 3                       22                        3                  5
# 4                       34                        8                 11
#
# [5 rows x 54 columns]
